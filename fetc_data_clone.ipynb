# %%
from bs4 import BeautifulSoup
import requests
import re
import time

# %%
url = 'https://onepiece.fandom.com/wiki/Eustass_Kid' # Char's wiki URL

response = requests.get(url)
html = response.content
soup = BeautifulSoup(html,'html.parser')

# %% [markdown]
# ## Getting the name of the char

# %%
#--------GET NAME----------#
def get_name(soup):
    try:
        aside = soup.find_all('aside')
        get_name_text = aside[0].find('h2')
        return get_name_text.get_text()
    except:
        return 'Unknown'

#--------GET NAME----------#

# %% [markdown]
# ## Getting the affiliation of the char

# %%
#-------------GET AFFILIATION---------------------------#
def get_affiliation(soup):
    try:
        affiliation = soup.find(attrs={"data-source": "affiliation"})
        get_affiliation_text = affiliation.find('a')
        return get_affiliation_text.get_text()
    except:
        return 'Unknown'
#-------------GET AFFILIATION---------------------------#

# %% [markdown]
# ## Getting the Devil Fruit of the char

# %%
#------------GET DEVIL FRUIT---------------------------#
def get_devil_fruit(soup):
    try:
        devilfruit = soup.find(attrs={"data-source": "dftype"})
        get_devilfruit_text = devilfruit.find('a')
        if get_devilfruit_text == 'Mythical Zoan':
           get_devilfruit_text = 'Zoan'
        return get_devilfruit_text.get_text()
    except:
        return 'None'
#------------GET DEVIL FRUIT---------------------------#

# %% [markdown]
# ## Getting the Haki Users ##

# %%
##---------------GET HAKI USER------------------##
def get_haki_users():
    haki_user_type = 0  # 0 for all, 1 for sao, 2 for oaa, 3 for oo, 4 for oa 
    all_haki = []
    sao = []
    oaa = []
    oo = []
    oa = []
    
    haki_users = {'All Types': None,
                  'Supreme King And Observation': None,
                  'Observation And Armament': None,
                  'Only Observation': None,
                  'Only Armament': None}

    haki_url = 'https://onepiece.fandom.com/wiki/Haki'
    haki_response = requests.get(haki_url)
    haki_html  = haki_response.content
    haki_soup = BeautifulSoup(haki_html, 'html.parser')

    haki_tbody = haki_soup.find_all('small')

    for current_user in haki_tbody:
        user = current_user.get_text()

        if user == 'John Giant':
            break
        
        if user == 'Marcus Mars':
            haki_user_type = 1
        elif user == 'Boa Marigold':
            haki_user_type = 2
        elif user == 'Satori':
            haki_user_type = 3
        elif user == 'Marguerite':
            haki_user_type = 4

        if user == 'Joy Boy':
            continue
        elif haki_user_type == 0: 
            all_haki.append(user)
        elif haki_user_type == 1:
            sao.append(user)
        elif haki_user_type == 2: 
            oaa.append(user)
        elif haki_user_type == 3: 
            oo.append(user)
        elif haki_user_type == 4: 
            oa.append(user)

    # Haki kullanıcılarını temizleme
    all_haki = [re.sub(r'\s*\(.*?\)|\xa0|\†|≠|\?', '', char).strip() for char in all_haki]
    oaa = [re.sub(r'\s*\(.*?\)|\xa0|\†|≠|\?', '', char).strip() for char in oaa]
    oo = [re.sub(r'\s*\(.*?\)|\xa0|\†|≠|\?', '', char).strip() for char in oo]
    oa = [re.sub(r'\s*\(.*?\)|\xa0|\†|≠|\?', '', char).strip() for char in oa]

    haki_users['All Types'] = all_haki
    haki_users['Supreme King And Observation'] = sao
    haki_users['Observation And Armament'] = oaa
    haki_users['Only Observation'] = oo
    haki_users['Only Armament'] = oa

    return haki_users


##---------------GET HAKI USER------------------##

# %% [markdown]
# ## Getting the bounty if exists

# %%
#-------------------GET BOUNTY---------------------#
def get_bounty(soup):
    try:
        bounty = soup.find(attrs={"data-source": "bounty"})
        get_bounty_text = bounty.find('div')
        bounty_text = get_bounty_text.get_text().split('[')[0].replace(',', '').replace('(', '').replace(')', '')
        return bounty_text
    except:
        return 'Unknown'
#-------------------GET BOUNTY---------------------#

# %% [markdown]
# ## Getting the height of Char

# %%
#----------------GET HEIGHT---------------#
def get_height(soup):
    try:
        height = soup.find(attrs={"data-source": "height"})
        get_height_text = height.find('div')
        height_text = get_height_text.get_text()

        heights = re.findall(r'\d+\s*cm', height_text)
        if heights:
            latest_height = heights[-1]
            latest_height = int(re.sub(r'\s*cm', '', latest_height))
            return latest_height
        else:
            return 'Unknown'
    except:
        return 'Unknown'
#----------------GET HEIGHT---------------#

# %% [markdown]
# ## Getting the Image of Char

# %%
#---------------GET IMAGE-------------------#
def get_image(soup,test):
    image = soup.find('aside')
    image_a = image.find('img')

    source = image_a['srcset']

    filename = test.translate(str.maketrans('ıİçÇşŞğĞüÜöÖ ', 'iIcCsSgGuUoO_')) + ".jpg"

    photo = requests.get(source)

    if photo.status_code != 200:
       print('Something went wrong')
    else:
       with open(filename, 'wb') as f:
           f.write(photo.content)
           print(f"{filename} başarıyla kaydedildi.")

    return filename

#---------------GET IMAGE-------------------#

# %% [markdown]
# ## Getting where the character is from

# %%
#--------------------GET ORIGIN-----------------#
def get_origin(soup):
    try:
        origin = soup.find(attrs={"data-source": "origin"})
        get_origin_text = origin.find('a')
        return get_origin_text.get_text()
    except:
        return 'Unknown'
#--------------------GET ORIGIN-----------------#

# %%
haki_users = get_haki_users()


def get_character_data(url, haki_users):
    character_info = {}
    
    
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    

    name_of_char = get_name(soup)
    character_info['name'] = get_name(soup)
    character_info['affiliation'] = get_affiliation(soup)
    character_info['devil_fruit'] = get_devil_fruit(soup)
    character_info['bounty'] = get_bounty(soup)
    character_info['height'] = get_height(soup)
    character_info['origin'] = get_origin(soup)
    character_info['haki'] = 'None'
    character_info['image'] = get_image(soup,test=name_of_char)

    for haki_type, haki_list in haki_users.items():
        if character_info['name'] in haki_list:
            character_info['haki'] = haki_type
            break

    return character_info

# %%
haki_users = get_haki_users()


character_urls = {
    "Monkey D. Luffy": "https://onepiece.fandom.com/wiki/Monkey_D._Luffy",
    "Roronoa Zoro": "https://onepiece.fandom.com/wiki/Roronoa_Zoro",
    "Nami": "https://onepiece.fandom.com/wiki/Nami",
    "Usopp": "https://onepiece.fandom.com/wiki/Usopp",
    "Sanji": "https://onepiece.fandom.com/wiki/Sanji",
    "Tony Tony Chopper": "https://onepiece.fandom.com/wiki/Tony_Tony_Chopper",
    "Nico Robin": "https://onepiece.fandom.com/wiki/Nico_Robin",
    "Franky": "https://onepiece.fandom.com/wiki/Franky",
    "Brook": "https://onepiece.fandom.com/wiki/Brook",
    "Jinbe": "https://onepiece.fandom.com/wiki/Jinbe",
    "Portgas D. Ace": "https://onepiece.fandom.com/wiki/Portgas_D._Ace",
    "Shanks": "https://onepiece.fandom.com/wiki/Shanks",
    "Edward Newgate (Whitebeard)": "https://onepiece.fandom.com/wiki/Edward_Newgate",
    "Gol D. Roger": "https://onepiece.fandom.com/wiki/Gol_D._Roger",
    "Silvers Rayleigh": "https://onepiece.fandom.com/wiki/Silvers_Rayleigh",
    "Buggy": "https://onepiece.fandom.com/wiki/Buggy",
    "Dracule Mihawk": "https://onepiece.fandom.com/wiki/Dracule_Mihawk",
    "Boa Hancock": "https://onepiece.fandom.com/wiki/Boa_Hancock",
    "Donquixote Doflamingo": "https://onepiece.fandom.com/wiki/Donquixote_Doflamingo",
    "Crocodile": "https://onepiece.fandom.com/wiki/Crocodile",
    "Enel": "https://onepiece.fandom.com/wiki/Enel",
    "Trafalgar D. Water Law": "https://onepiece.fandom.com/wiki/Trafalgar_D._Water_Law",
    "Eustass Kid": "https://onepiece.fandom.com/wiki/Eustass_Kid",
    "Kaido": "https://onepiece.fandom.com/wiki/Kaido",
    "Charlotte Linlin (Big Mom)": "https://onepiece.fandom.com/wiki/Charlotte_Linlin",
    "Marshall D. Teach (Blackbeard)": "https://onepiece.fandom.com/wiki/Marshall_D._Teach",
    "Sabo": "https://onepiece.fandom.com/wiki/Sabo",
    "Kozuki Oden": "https://onepiece.fandom.com/wiki/Kozuki_Oden",
    "Killer": "https://onepiece.fandom.com/wiki/Killer",
    "Kin'emon": "https://onepiece.fandom.com/wiki/Kin%27emon",
    "Smoker": "https://onepiece.fandom.com/wiki/Smoker",
    "Sengoku": "https://onepiece.fandom.com/wiki/Sengoku",
    "Monkey D. Garp": "https://onepiece.fandom.com/wiki/Monkey_D._Garp",
    "Sakazuki (Akainu)": "https://onepiece.fandom.com/wiki/Sakazuki",
    "Borsalino (Kizaru)": "https://onepiece.fandom.com/wiki/Borsalino",
    "Issho (Fujitora)": "https://onepiece.fandom.com/wiki/Issho",
    "Kuzan (Aokiji)": "https://onepiece.fandom.com/wiki/Kuzan",
    "Donquixote Rosinante": "https://onepiece.fandom.com/wiki/Donquixote_Rosinante",
    "Bartolomeo": "https://onepiece.fandom.com/wiki/Bartolomeo",
    "Cavendish": "https://onepiece.fandom.com/wiki/Cavendish",
    "Bellamy": "https://onepiece.fandom.com/wiki/Bellamy",
    "Pedro": "https://onepiece.fandom.com/wiki/Pedro",
    "Carrot": "https://onepiece.fandom.com/wiki/Carrot",
    "Shirahoshi": "https://onepiece.fandom.com/wiki/Shirahoshi",
    "Vinsmoke Reiju": "https://onepiece.fandom.com/wiki/Vinsmoke_Reiju",
    "Vinsmoke Judge": "https://onepiece.fandom.com/wiki/Vinsmoke_Judge",
    "Hody Jones": "https://onepiece.fandom.com/wiki/Hody_Jones",
    "Caesar Clown": "https://onepiece.fandom.com/wiki/Caesar_Clown",
    "Capone Bege": "https://onepiece.fandom.com/wiki/Capone_Bege",
    "Katakuri": "https://onepiece.fandom.com/wiki/Charlotte_Katakuri",
    "Pekoms": "https://onepiece.fandom.com/wiki/Pekoms",
    "Vivi": "https://onepiece.fandom.com/wiki/Nefertari_Vivi",
    "Marco": "https://onepiece.fandom.com/wiki/Marco",
    "Jozu": "https://onepiece.fandom.com/wiki/Jozu",
    "Vista": "https://onepiece.fandom.com/wiki/Vista",
    "King": "https://onepiece.fandom.com/wiki/King",
    "Queen": "https://onepiece.fandom.com/wiki/Queen",
    "Jack": "https://onepiece.fandom.com/wiki/Jack",
    "X Drake": "https://onepiece.fandom.com/wiki/X_Drake",
    "Scratchmen Apoo": "https://onepiece.fandom.com/wiki/Scratchmen_Apoo",
    "Basil Hawkins": "https://onepiece.fandom.com/wiki/Basil_Hawkins",
    "Ulti": "https://onepiece.fandom.com/wiki/Ulti",
    "Page One": "https://onepiece.fandom.com/wiki/Page_One",
    "Black Maria": "https://onepiece.fandom.com/wiki/Black_Maria",
    "Who's-Who": "https://onepiece.fandom.com/wiki/Who's-Who",
    "Sasaki": "https://onepiece.fandom.com/wiki/Sasaki",
    "Kiku": "https://onepiece.fandom.com/wiki/Kikunojo",
    "Denjiro": "https://onepiece.fandom.com/wiki/Denjiro",
    "Kawamatsu": "https://onepiece.fandom.com/wiki/Kawamatsu",
    "Raizo": "https://onepiece.fandom.com/wiki/Raizo",
    "Orochi": "https://onepiece.fandom.com/wiki/Kurozumi_Orochi",
    "Yamato": "https://onepiece.fandom.com/wiki/Yamato",
    "Tama": "https://onepiece.fandom.com/wiki/Tama",
    "Kin'emon": "https://onepiece.fandom.com/wiki/Kin%27emon",
    "Perona": "https://onepiece.fandom.com/wiki/Perona",
    "Shiki": "https://onepiece.fandom.com/wiki/Shiki",
    "Zephyr": "https://onepiece.fandom.com/wiki/Zephyr"
}


character_data = {}


for character, url in character_urls.items():
    print(f"fetching data for {character} ")
    character_data[character] = get_character_data(url, haki_users)
    
    
    time.sleep(2)


print(character_data)
# Out:
# fetching data for Monkey D. Luffy
# Monkey_D._Luffy.jpg başarıyla kaydedildi.
# fetching data for Roronoa Zoro
# Roronoa_Zoro.jpg başarıyla kaydedildi.
# fetching data for Nami
# Nami.jpg başarıyla kaydedildi.
# fetching data for Usopp
# Usopp.jpg başarıyla kaydedildi.
# fetching data for Sanji
# Sanji.jpg başarıyla kaydedildi.
# fetching data for Tony Tony Chopper
# Tony_Tony_Chopper.jpg başarıyla kaydedildi.
# fetching data for Nico Robin
# Nico_Robin.jpg başarıyla kaydedildi.
# fetching data for Franky
# Franky.jpg başarıyla kaydedildi.
# fetching data for Brook
# Brook.jpg başarıyla kaydedildi.
# fetching data for Jinbe
# Jinbe.jpg başarıyla kaydedildi.
# fetching data for Portgas D. Ace
# Portgas_D._Ace.jpg başarıyla kaydedildi.
# fetching data for Shanks
# Shanks.jpg başarıyla kaydedildi.
# fetching data for Edward Newgate (Whitebeard)
# Edward_Newgate.jpg başarıyla kaydedildi.
# fetching data for Gol D. Roger
# Gol_D._Roger.jpg başarıyla kaydedildi.
# fetching data for Silvers Rayleigh
# Silvers_Rayleigh.jpg başarıyla kaydedildi.
# fetching data for Buggy
# Buggy.jpg başarıyla kaydedildi.
# fetching data for Dracule Mihawk
# Dracule_Mihawk.jpg başarıyla kaydedildi.
# fetching data for Boa Hancock
# Boa_Hancock.jpg başarıyla kaydedildi.
# fetching data for Donquixote Doflamingo
# Donquixote_Doflamingo.jpg başarıyla kaydedildi.
# fetching data for Crocodile
# Crocodile.jpg başarıyla kaydedildi.
# fetching data for Enel
# Enel.jpg başarıyla kaydedildi.
# fetching data for Trafalgar D. Water Law
# Trafalgar_D._Water_Law.jpg başarıyla kaydedildi.
# fetching data for Eustass Kid
# Eustass_Kid.jpg başarıyla kaydedildi.
# fetching data for Kaido
# Kaidou.jpg başarıyla kaydedildi.
# fetching data for Charlotte Linlin (Big Mom)
# Charlotte_Linlin.jpg başarıyla kaydedildi.
# fetching data for Marshall D. Teach (Blackbeard)
# Marshall_D._Teach.jpg başarıyla kaydedildi.
# fetching data for Sabo
# Sabo.jpg başarıyla kaydedildi.
# fetching data for Kozuki Oden
# Kouzuki_Oden.jpg başarıyla kaydedildi.
# fetching data for Killer
# Killer.jpg başarıyla kaydedildi.
# fetching data for Kin'emon
# Kin'emon.jpg başarıyla kaydedildi.
# fetching data for Smoker
# Smoker.jpg başarıyla kaydedildi.
# fetching data for Sengoku
# Sengoku.jpg başarıyla kaydedildi.
# fetching data for Monkey D. Garp
# Monkey_D._Garp.jpg başarıyla kaydedildi.
# fetching data for Sakazuki (Akainu)
# Sakazuki.jpg başarıyla kaydedildi.
# fetching data for Borsalino (Kizaru)
# Borsalino.jpg başarıyla kaydedildi.
# fetching data for Issho (Fujitora)
# Issho.jpg başarıyla kaydedildi.
# fetching data for Kuzan (Aokiji)
# Kuzan.jpg başarıyla kaydedildi.
# fetching data for Donquixote Rosinante
# Donquixote_Rosinante.jpg başarıyla kaydedildi.
# fetching data for Bartolomeo
# Bartolomeo.jpg başarıyla kaydedildi.
# fetching data for Cavendish
# Cavendish.jpg başarıyla kaydedildi.
# fetching data for Bellamy
# Bellamy.jpg başarıyla kaydedildi.
# fetching data for Pedro
# Pedro.jpg başarıyla kaydedildi.
# fetching data for Carrot
# Carrot.jpg başarıyla kaydedildi.
# fetching data for Shirahoshi
# Shirahoshi.jpg başarıyla kaydedildi.
# fetching data for Vinsmoke Reiju
# Vinsmoke_Reiju.jpg başarıyla kaydedildi.
# fetching data for Vinsmoke Judge
# Vinsmoke_Judge.jpg başarıyla kaydedildi.
# fetching data for Hody Jones
# Hody_Jones.jpg başarıyla kaydedildi.
# fetching data for Caesar Clown
# Caesar_Clown.jpg başarıyla kaydedildi.
# fetching data for Capone Bege
# Capone_Bege.jpg başarıyla kaydedildi.
# fetching data for Katakuri
# Charlotte_Katakuri.jpg başarıyla kaydedildi.
# fetching data for Pekoms
# Pekoms.jpg başarıyla kaydedildi.
# fetching data for Vivi
# Nefertari_Vivi.jpg başarıyla kaydedildi.
# fetching data for Marco
# Marco.jpg başarıyla kaydedildi.
# fetching data for Jozu
# Jozu.jpg başarıyla kaydedildi.
# fetching data for Vista
# Vista.jpg başarıyla kaydedildi.
# fetching data for King
# King.jpg başarıyla kaydedildi.
# fetching data for Queen
# Queen.jpg başarıyla kaydedildi.
# fetching data for Jack
# Jack.jpg başarıyla kaydedildi.
# fetching data for X Drake
# X_Drake.jpg başarıyla kaydedildi.
# fetching data for Scratchmen Apoo
# Scratchmen_Apoo.jpg başarıyla kaydedildi.
# fetching data for Basil Hawkins
# Basil_Hawkins.jpg başarıyla kaydedildi.
# fetching data for Ulti
# Ulti.jpg başarıyla kaydedildi.
# fetching data for Page One
# Page_One.jpg başarıyla kaydedildi.
# fetching data for Black Maria
# Black_Maria.jpg başarıyla kaydedildi.
# fetching data for Who's-Who
# Who's-Who.jpg başarıyla kaydedildi.
# fetching data for Sasaki
# Sasaki.jpg başarıyla kaydedildi.
# fetching data for Kiku
# Kikunojo.jpg başarıyla kaydedildi.
# fetching data for Denjiro
# Denjiro.jpg başarıyla kaydedildi.
# fetching data for Kawamatsu
# Kawamatsu.jpg başarıyla kaydedildi.
# fetching data for Raizo
# Raizo.jpg başarıyla kaydedildi.
# fetching data for Orochi
# Kurozumi_Orochi.jpg başarıyla kaydedildi.
# fetching data for Yamato
# Yamato.jpg başarıyla kaydedildi.
# fetching data for Tama
# Kurozumi_Tama.jpg başarıyla kaydedildi.
# fetching data for Perona
# Perona.jpg başarıyla kaydedildi.
# fetching data for Shiki
# Shiki.jpg başarıyla kaydedildi.
# fetching data for Zephyr
# Z.jpg başarıyla kaydedildi.
# {'Monkey D. Luffy': {'name': 'Monkey D. Luffy', 'affiliation': 'Straw Hat Pirates', 'devil_fruit': 'Paramecia', 'bounty': '3000000000', 'height': 174, 'origin': 'East Blue', 'haki': 'All Types', 'image': 'Monkey_D._Luffy.jpg'}, 'Roronoa Zoro': {'name': 'Roronoa Zoro', 'affiliation': 'Straw Hat Pirates', 'devil_fruit': 'None', 'bounty': '1111000000', 'height': 181, 'origin': 'East Blue', 'haki': 'All Types', 'image': 'Roronoa_Zoro.jpg'}, 'Nami': {'name': 'Nami', 'affiliation': 'Straw Hat Pirates', 'devil_fruit': 'None', 'bounty': '366000000', 'height': 170, 'origin': 'East Blue', 'haki': 'None', 'image': 'Nami.jpg'}, 'Usopp': {'name': 'Usopp', 'affiliation': 'Straw Hat Pirates', 'devil_fruit': 'None', 'bounty': '500000000', 'height': 176, 'origin': 'East Blue', 'haki': 'Only Observation', 'image': 'Usopp.jpg'}, 'Sanji': {'name': 'Sanji', 'affiliation': 'Straw Hat Pirates', 'devil_fruit': 'None', 'bounty': '1032000000', 'height': 180, 'origin': 'North Blue', 'haki': 'Observation And Armament', 'image': 'Sanji.jpg'}, 'Tony Tony Chopper': {'name': 'Tony Tony Chopper', 'affiliation': 'Straw Hat Pirates', 'devil_fruit': 'Zoan', 'bounty': '1000', 'height': 90, 'origin': 'Grand Line', 'haki': 'None', 'image': 'Tony_Tony_Chopper.jpg'}, 'Nico Robin': {'name': 'Nico Robin', 'affiliation': 'Straw Hat Pirates', 'devil_fruit': 'Paramecia', 'bounty': '930000000', 'height': 188, 'origin': 'West Blue', 'haki': 'None', 'image': 'Nico_Robin.jpg'}, 'Franky': {'name': 'Franky', 'affiliation': 'Straw Hat Pirates', 'devil_fruit': 'None', 'bounty': '394000000', 'height': 240, 'origin': 'South Blue', 'haki': 'None', 'image': 'Franky.jpg'}, 'Brook': {'name': 'Brook', 'affiliation': 'Straw Hat Pirates', 'devil_fruit': 'Paramecia', 'bounty': '383000000', 'height': 277, 'origin': 'West Blue', 'haki': 'None', 'image': 'Brook.jpg'}, 'Jinbe': {'name': 'Jinbe', 'affiliation': 'Straw Hat Pirates', 'devil_fruit': 'None', 'bounty': '1100000000', 'height': 301, 'origin': 'Grand Line', 'haki': 'Observation And Armament', 'image': 'Jinbe.jpg'}, 'Portgas D. Ace': {'name': 'Portgas D. Ace', 'affiliation': 'Whitebeard Pirates', 'devil_fruit': 'Logia', 'bounty': '550000000', 'height': 103, 'origin': 'South Blue', 'haki': 'All Types', 'image': 'Portgas_D._Ace.jpg'}, 'Shanks': {'name': 'Shanks', 'affiliation': 'Red Hair Pirates', 'devil_fruit': 'None', 'bounty': '4048900000', 'height': 132, 'origin': 'West Blue', 'haki': 'All Types', 'image': 'Shanks.jpg'}, 'Edward Newgate (Whitebeard)': {'name': 'Edward Newgate', 'affiliation': 'Whitebeard Pirates', 'devil_fruit': 'Paramecia', 'bounty': '5046000000', 'height': 666, 'origin': 'Grand Line', 'haki': 'All Types', 'image': 'Edward_Newgate.jpg'}, 'Gol D. Roger': {'name': 'Gol D. Roger', 'affiliation': 'Roger Pirates', 'devil_fruit': 'None', 'bounty': '5564800000', 'height': 274, 'origin': 'East Blue', 'haki': 'All Types', 'image': 'Gol_D._Roger.jpg'}, 'Silvers Rayleigh': {'name': 'Silvers Rayleigh', 'affiliation': 'Roger Pirates', 'devil_fruit': 'None', 'bounty': 'Unknown', 'height': 188, 'origin': 'Unknown', 'haki': 'All Types', 'image': 'Silvers_Rayleigh.jpg'}, 'Buggy': {'name': 'Buggy', 'affiliation': 'Cross Guild', 'devil_fruit': 'Paramecia', 'bounty': '3189000000', 'height': 130, 'origin': 'Grand Line', 'haki': 'None', 'image': 'Buggy.jpg'}, 'Dracule Mihawk': {'name': 'Dracule Mihawk', 'affiliation': 'Cross Guild', 'devil_fruit': 'None', 'bounty': '3590000000', 'height': 198, 'origin': 'Unknown', 'haki': 'Observation And Armament', 'image': 'Dracule_Mihawk.jpg'}, 'Boa Hancock': {'name': 'Boa Hancock', 'affiliation': 'Kuja', 'devil_fruit': 'Paramecia', 'bounty': '1659000000', 'height': 191, 'origin': 'Calm Belt', 'haki': 'All Types', 'image': 'Boa_Hancock.jpg'}, 'Donquixote Doflamingo': {'name': 'Donquixote Doflamingo', 'affiliation': 'Donquixote Pirates', 'devil_fruit': 'Paramecia', 'bounty': '340000000', 'height': 305, 'origin': 'Red Line', 'haki': 'All Types', 'image': 'Donquixote_Doflamingo.jpg'}, 'Crocodile': {'name' ...

# %%
import pandas as pd

df = pd.DataFrame.from_dict(character_data, orient='index')
df.reset_index(inplace=True)
df.rename(columns={'index': 'character_name'}, inplace=True)
df = df.drop(['character_name'],axis = 1)

# %%
df_copy = df

# %%
df_copy
# Out:
#                name                         affiliation    devil_fruit  \
# 0   Monkey D. Luffy                   Straw Hat Pirates      Paramecia
# 1      Roronoa Zoro                   Straw Hat Pirates           None
# 2              Nami                   Straw Hat Pirates           None
# 3             Usopp                   Straw Hat Pirates           None
# 4             Sanji                   Straw Hat Pirates           None
# ..              ...                                 ...            ...
# 71           Yamato  Ninja-Pirate-Mink-Samurai Alliance  Mythical Zoan
# 72    Kurozumi Tama                     Kurozumi Family      Paramecia
# 73           Perona                      Dracule Mihawk      Paramecia
# 74            Shiki                 Golden Lion Pirates      Paramecia
# 75                Z                         Neo Marines           None
#
#         bounty   height      origin                      haki  \
# 0   3000000000      174   East Blue                 All Types
# 1   1111000000      181   East Blue                 All Types
# 2    366000000      170   East Blue                      None
# 3    500000000      176   East Blue          Only Observation
# 4   1032000000      180  North Blue  Observation And Armament
# ..         ...      ...         ...                       ...
# 71     Unknown      263     Unknown                 All Types
# 72     Unknown      108     Unknown                      None
# 73     Unknown      160   West Blue                      None
# 74     Unknown  Unknown     Unknown                      None
# 75     Unknown      348     Unknown                      None
#
#                   image
# 0   Monkey_D._Luffy.jpg
# 1      Roronoa_Zoro.jpg
# 2              Nami.jpg
# 3             Usopp.jpg
# 4             Sanji.jpg
# ..                  ...
# 71           Yamato.jpg
# 72    Kurozumi_Tama.jpg
# 73           Perona.jpg
# 74            Shiki.jpg
# 75                Z.jpg
#
# [76 rows x 8 columns]

# %%
df_copy['devil_fruit'].unique()
# Out:
# array(['Paramecia', 'None', 'Zoan', 'Logia', 'Mythical Zoan',
#        'Special Paramecia', 'Ancient Zoan'], dtype=object)

# %%
df_copy['origin'].unique()
# Out:
# array(['East Blue', 'North Blue', 'Grand Line', 'West Blue', 'South Blue',
#        'Unknown', 'Calm Belt', 'Red Line', 'Sky Islands',
#        'Kutsukku Island', 'Wano Country'], dtype=object)

# %%
for i in range(0,len(df_copy)-1):

    if df_copy['origin'][i] == 'Wano Country' or df_copy['origin'][i] == 'Sky Islands':
        df_copy['origin'][i] = 'Grand Line' 
    if df_copy['origin'][i] == 'Kutsukku Island':
        df_copy['origin'][i] = 'South Blue'

# %%
df_copy['origin'].unique()
# Out:
# array(['East Blue', 'North Blue', 'Grand Line', 'West Blue', 'South Blue',
#        'Unknown', 'Calm Belt', 'Red Line'], dtype=object)

# %%
df_copy['devil_fruit'].unique()
# Out:
# array(['Paramecia', 'None', 'Zoan', 'Logia', 'Mythical Zoan',
#        'Special Paramecia', 'Ancient Zoan'], dtype=object)

# %%
for i in range(0,len(df_copy)-1):

    if df['devil_fruit'][i] == 'Mythical Zoan' or df['devil_fruit'][i] == 'Ancient Zoan':
        df['devil_fruit'][i] = 'Zoan'
    if df['devil_fruit'][i] == 'Special Paramecia':
        df['devil_fruit'][i] = 'Paramecia'

# %%
df_copy['devil_fruit'].unique()
# Out:
# array(['Paramecia', 'None', 'Zoan', 'Logia'], dtype=object)

# %%
df_copy.to_csv('character_data.csv', index=True)
